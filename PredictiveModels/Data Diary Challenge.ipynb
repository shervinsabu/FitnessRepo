# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('drive/MyDrive/sher/sleepDay_merged.csv')

# %%
df
# Out:
#                   SleepDay  TotalMinutesAsleep  TotalTimeInBed     Sleep Type
# 0            04/12/16 0:00                 327             346     Deep Sleep
# 1    4/13/2016 12:00:00 AM                 384             407     Deep Sleep
# 2    4/15/2016 12:00:00 AM                 412             442     Deep Sleep
# 3    4/16/2016 12:00:00 AM                 340             367     Deep Sleep
# 4    4/17/2016 12:00:00 AM                 700             712  Deepest Sleep
# ..                     ...                 ...             ...            ...
# 408  4/30/2016 12:00:00 AM                 343             360     Deep Sleep
# 409          05/01/16 0:00                 503             527  Deepest Sleep
# 410          05/02/16 0:00                 415             423     Deep Sleep
# 411          05/03/16 0:00                 516             545  Deepest Sleep
# 412          05/04/16 0:00                 439             463     Deep Sleep
#
# [413 rows x 4 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                   SleepDay  TotalMinutesAsleep  TotalTimeInBed     Sleep Type
# 0            04/12/16 0:00                 327             346     Deep Sleep
# 1    4/13/2016 12:00:00 AM                 384             407     Deep Sleep
# 2    4/15/2016 12:00:00 AM                 412             442     Deep Sleep
# 3    4/16/2016 12:00:00 AM                 340             367     Deep Sleep
# 4    4/17/2016 12:00:00 AM                 700             712  Deepest Sleep
# ..                     ...                 ...             ...            ...
# 408  4/30/2016 12:00:00 AM                 343             360     Deep Sleep
# 409          05/01/16 0:00                 503             527  Deepest Sleep
# 410          05/02/16 0:00                 415             423     Deep Sleep
# 411          05/03/16 0:00                 516             545  Deepest Sleep
# 412          05/04/16 0:00                 439             463     Deep Sleep
#
# ...

# %%
df.shape
# Out:
# (413, 4)

# %%
df.isnull().sum()
# Out:
# SleepDay              0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# Sleep Type            0
# dtype: int64

# %%
df.head()
# Out:
#                 SleepDay  TotalMinutesAsleep  TotalTimeInBed     Sleep Type
# 0          04/12/16 0:00                 327             346     Deep Sleep
# 1  4/13/2016 12:00:00 AM                 384             407     Deep Sleep
# 2  4/15/2016 12:00:00 AM                 412             442     Deep Sleep
# 3  4/16/2016 12:00:00 AM                 340             367     Deep Sleep
# 4  4/17/2016 12:00:00 AM                 700             712  Deepest Sleep

# %%
df.shape
# Out:
# (413, 4)

# %%
df.isnull().sum()
# Out:
# SleepDay              0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# Sleep Type            0
# dtype: int64

# %%
duplicate_rows_newdf = df[df.duplicated()]
duplicate_rows_newdf
# Out:
#                   SleepDay  TotalMinutesAsleep  TotalTimeInBed     Sleep Type
# 161          05/05/16 0:00                 471             495     Deep Sleep
# 223          05/07/16 0:00                 520             543  Deepest Sleep
# 323  4/29/2016 12:00:00 AM                 433             447     Deep Sleep
# 380  4/25/2016 12:00:00 AM                 388             402     Deep Sleep

# %%
df['Sleep Type'].replace(['Light Sleep','Deep Sleep','Deepest Sleep'],[0,1,2],inplace=True)

# %%
df.head()
# Out:
#                 SleepDay  TotalMinutesAsleep  TotalTimeInBed  Sleep Type
# 0          04/12/16 0:00                 327             346           1
# 1  4/13/2016 12:00:00 AM                 384             407           1
# 2  4/15/2016 12:00:00 AM                 412             442           1
# 3  4/16/2016 12:00:00 AM                 340             367           1
# 4  4/17/2016 12:00:00 AM                 700             712           2

# %%
df['Sleep Type'].value_counts().sort_values(ascending=True)
# Out:
# 0     50
# 2     91
# 1    272
# Name: Sleep Type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.dtypes
# Out:
# SleepDay              object
# TotalMinutesAsleep     int64
# TotalTimeInBed         int64
# Sleep Type             int64
# dtype: object

# %%
new_df = df

# %%
new_df
# Out:
#                   SleepDay  TotalMinutesAsleep  TotalTimeInBed  Sleep Type
# 0            04/12/16 0:00                 327             346           1
# 1    4/13/2016 12:00:00 AM                 384             407           1
# 2    4/15/2016 12:00:00 AM                 412             442           1
# 3    4/16/2016 12:00:00 AM                 340             367           1
# 4    4/17/2016 12:00:00 AM                 700             712           2
# ..                     ...                 ...             ...         ...
# 408  4/30/2016 12:00:00 AM                 343             360           1
# 409          05/01/16 0:00                 503             527           2
# 410          05/02/16 0:00                 415             423           1
# 411          05/03/16 0:00                 516             545           2
# 412          05/04/16 0:00                 439             463           1
#
# [413 rows x 4 columns]

# %%
lb_make = LabelEncoder()
new_df['SleepDay'] = lb_make.fit_transform(new_df['SleepDay'])

# %%
new_df
# Out:
#      SleepDay  TotalMinutesAsleep  TotalTimeInBed  Sleep Type
# 0           0                 327             346           1
# 1          13                 384             407           1
# 2          15                 412             442           1
# 3          16                 340             367           1
# 4          17                 700             712           2
# ..        ...                 ...             ...         ...
# 408        30                 343             360           1
# 409         1                 503             527           2
# 410         2                 415             423           1
# 411         3                 516             545           2
# 412         4                 439             463           1
#
# [413 rows x 4 columns]

# %%
df.dtypes
# Out:
# SleepDay              int64
# TotalMinutesAsleep    int64
# TotalTimeInBed        int64
# Sleep Type            int64
# dtype: object

# %%
x = new_df.drop(['Sleep Type'],axis=1)

# %%
x
# Out:
#      SleepDay  TotalMinutesAsleep  TotalTimeInBed
# 0           0                 327             346
# 1          13                 384             407
# 2          15                 412             442
# 3          16                 340             367
# 4          17                 700             712
# ..        ...                 ...             ...
# 408        30                 343             360
# 409         1                 503             527
# 410         2                 415             423
# 411         3                 516             545
# 412         4                 439             463
#
# [413 rows x 3 columns]

# %%
y = new_df['Sleep Type']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      2
#       ..
# 408    1
# 409    2
# 410    1
# 411    2
# 412    1
# Name: Sleep Type, Length: 413, dtype: int64

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
df2 = pd.DataFrame(scaler.fit_transform(x))
df2
# Out:
#             0         1         2
# 0   -1.692043 -0.782287 -0.887289
# 1   -0.263650 -0.300059 -0.406776
# 2   -0.043897 -0.063175 -0.131072
# 3    0.065979 -0.672305 -0.721866
# 4    0.175855  2.373347  1.995790
# ..        ...       ...       ...
# 408  1.604248 -0.646924 -0.777007
# 409 -1.582167  0.706698  0.538496
# 410 -1.472290 -0.037794 -0.280740
# 411 -1.362414  0.816680  0.680287
# 412 -1.252537  0.165249  0.034351
#
# [413 rows x 3 columns]

# %%
x_trans = scaler.fit_transform(x)
x_trans
# Out:
# array([[-1.69204299, -0.78228664, -0.88728886],
#        [-0.26365009, -0.30005852, -0.40677579],
#        [-0.04389734, -0.06317453, -0.13107156],
#        ...,
#        [-1.47229024, -0.0377941 , -0.28073957],
#        [-1.36241386,  0.8166803 ,  0.68028658],
#        [-1.25253748,  0.16524932,  0.03435097]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_trans, y, test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9919354838709677

# %%
from sklearn.metrics import f1_score
f1_score(y_test,y_pred,average='weighted')
# Out:
# 0.9076927452465285

# %%
from sklearn.metrics import f1_score,recall_score
recall_score(y_test,y_pred,average='weighted')
# Out:
# 0.9112903225806451

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[11,  0,  0],
#        [ 0, 85,  1],
#        [ 0,  0, 27]])

# %%
from sklearn.metrics import ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred))
disp.plot()

# %%
from sklearn.metrics import classification_report
from sklearn import metrics
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.99      0.99        86
#            2       0.96      1.00      0.98        27
#
#     accuracy                           0.99       124
#    macro avg       0.99      1.00      0.99       124
# weighted avg       0.99      0.99      0.99       124

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9112903225806451

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
gau = GaussianNB()
gau.fit(x_train,y_train)
y_pred = gau.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9516129032258065

# %%
from scipy import interp
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.linear_model import LogisticRegression
# Learn to predict each class against the other
yhat = gau.predict_proba(x_test)
y_test_bin = label_binarize(y_test,classes=np.unique(y_test))
n_classes = len(np.unique(y_test)) # number of class
# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = dict()
thresh = {}
for i in range(n_classes):
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test_bin[:, i], yhat[:, i],drop_intermediate=False)
    roc_auc[i] = auc(fpr[i], tpr[i])
    plt.figure()
    lw = 2 # line_width
    plt.plot(fpr[i], tpr[i], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[i]) 

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('MultiClass ROC Curve')
plt.legend(loc="lower right")
plt.show()
